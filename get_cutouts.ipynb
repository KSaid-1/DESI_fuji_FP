# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
fuji_data = pd.read_csv("fuji_FPT-fibermap-good-guys-results.txt")

# %%
fuji_data_10 = fuji_data[4000:]
fuji_data_10
# Out:
#       #fibermap_targetid  fibermap_i          ra        dec  \
# 4000   39628449286982584         495  195.832509  28.617252
# 4001   39628351639393330        1085  195.833066  23.942522
# 4002   39628427925390809         698  195.833572  27.441168
# 4003   39628443964411673         857  195.839818  28.309009
# 4004   39628438633447801        1469  195.844885  27.935949
# ...                  ...         ...         ...        ...
# 7094   39628462264159624         479  357.084339  28.895477
# 7095   39628451673539259           0  357.210430  28.577718
# 7096   39628456975140195           2  357.247043  28.635471
# 7097   39628467548982836         300  357.637918  29.203475
# 7098   39628472817030769          13  357.698194  29.597743
#
#                targetid    id  healpix survey program         targetid.1  ...  \
# 4000  39628449286982584  3171    10382    sv3  bright  39628449286982584  ...
# 4001  39628351639393330  3423    28116    sv3  bright  39628351639393330  ...
# ...

# %%
targetid = fuji_data_10["targetid"]
ra = fuji_data_10["ra"]
dec = fuji_data_10["dec"]
print (len(targetid))
print (targetid[4001],ra[4001],dec[4001])
# Out:
# 3099
# 39628351639393330 195.833065588648 23.942521657437

# %%
for i in range(4001,5001):
    #if os.path.isfile("./images/"+str(targetid[i])+".jpeg"):
    #    print ("wget -P . -O "+"./images/"+str(targetid[i])+".jpeg https://www.legacysurvey.org/viewer/jpeg-cutout?ra="+str(ra[i])+"\&dec="+str(dec[i])+"\&layer=ls-dr9\&pixscale=0.1\&bands=grz")
    #elif:
    print (targetid[i])
    os.system("wget -P . -O "+"./images/"+str(targetid[i])+".jpeg https://www.legacysurvey.org/viewer/jpeg-cutout?ra="+str(ra[i])+"\&dec="+str(dec[i])+"\&layer=ls-dr9\&pixscale=0.1\&bands=grz")
# Out:
# 39628351639393330
# 39628427925390809
# 39628443964411673
# 39628438633447801
# 39628454596971067
# 39628379141441574
# 39628384606619608
# 39628362674606667
# 39628373663681833
# 39628465179200601
# 39628422552488775
# 39628459894378717
# 39628449291174473
# 39628438633449214
# 39628443968603381
# 39628438633449651
# 39628465179202007
# 39628346111298479
# 39628433285712988
# 39628433285713047
# 39628443968603655
# 39628465179202330
# 39628368177529904
# 39628454601163941
# 39628438633450842
# 39628443968604544
# 39628459898569790
# 39628427929583907
# 39628443968604693
# 39628459898570303
# 39628449291176599
# 39628470455632650
# 39628422556681920
# 39628433289905623
# 39628368177533697
# 39628443972797814
# 39628454605357595
# 39628351647779500
# 39628433289907463
# 39628427929588541
# 39628443972798477
# 39628433289907887
# 39628368181724961
# 39628465187586390
# 39628465187586469
# 39628433289908461
# 39628368181726263
# 39628427933779461
# 39628459902765498
# 39628438641836237
# ...
